# %% [markdown]
# # **Use the PDBe API to retrieve information about the co-crystallized ligands of SOS1
#
# Son of Sevenless homolog 1**
#
# Retrieve PDB Entries for SOS1 and mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
job_description = '/content/drive/MyDrive/InterviewExercise'
import os
files = os.listdir(job_description)
print(files)
# Out:
# ['Copy_of_Job_Description_&_Exercices.ipynb', 'SOS1.json', '.ipynb_checkpoints', 'SOS1.csv']

# %% [markdown]
# # Task 1
# **Use the PDBe API to retrieve information about the co-crystallized ligands of SOS1. Leverage the JSON format to produce a well-organized CSV (index=PDBID) containing the most valuable data. Three-letter code and SMILES reppresentation are compulsory features.**

# %%
import requests # import the request module

# %%
uniprot_id = 'Q07889' # SOS1 UniprotID
url = f"https://www.ebi.ac.uk/pdbe/api/mappings/best_structures/Q07889" # to get the PDB entries that contain the compound from PDBe API url
# this retrieves the best PDB structure mappings available for SOS1 Q07889

# %%
entries = requests.get(url) # the request module help get data from the url

# %%
import json
#To be sure if the requests get was succesful
if entries.status_code == 200:
  print("Request successful")
  SOS1_data = entries.json()
  print(SOS1_data)
else:
  SOS1_data = None
  print(f"Data retrieval failed with status code: {entries.status_code}")
  print(entries.text)
# Out:
# Request successful
# {'Q07889': [{'pdb_id': '3ksy', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.787, 'resolution': 3.178, 'start': 1, 'end': 1049, 'unp_start': 1, 'unp_end': 1049}, {'pdb_id': '1xd4', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.639, 'resolution': 3.64, 'start': 1, 'end': 852, 'unp_start': 198, 'unp_end': 1049}, {'pdb_id': '1xd4', 'chain_id': 'B', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.639, 'resolution': 3.64, 'start': 1, 'end': 852, 'unp_start': 198, 'unp_end': 1049}, {'pdb_id': '1xdv', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.635, 'resolution': 4.1, 'start': 1, 'end': 847, 'unp_start': 198, 'unp_end': 1044}, {'pdb_id': '1xdv', 'chain_id': 'B', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.635, 'resolution': 4.1, 'start': 1, 'end': 847, 'unp_start': 198, 'unp_end': 1044}, {'pdb_id': '8xjj', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.44, 'resolution': 2.1, 'start': 5, 'end': 590, 'unp_start': 564, 'unp_end': 1149}, {'pdb_id': '5ove', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.368, 'resolution': 1.85, 'start': 1, 'end': 490, 'unp_start': 560, 'unp_end': 1049}, {'pdb_id': '5ovd', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.368, 'resolution': 1.9, 'start': 1, 'end': 490, 'unp_start': 560, 'unp_end': 1049}, {'pdb_id': '5ovf', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.368, 'resolution': 2.01, 'start': 1, 'end': 490, 'unp_start': 560, 'unp_end': 1049}, {'pdb_id': '5ovi', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.368, 'resolution': 2.2, 'start': 1, 'end': 490, 'unp_start': 560, 'unp_end': 1049}, {'pdb_id': '5ovg', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.368, 'resolution': 2.3, 'start': 1, 'end': 490, 'unp_start': 560, 'unp_end': 1049}, {'pdb_id': '5ovh', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.368, 'resolution': 2.3, 'start': 1, 'end': 490, 'unp_start': 560, 'unp_end': 1049}, {'pdb_id': '7avl', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.718, 'start': 2, 'end': 487, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '7avl', 'chain_id': 'B', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.718, 'start': 2, 'end': 487, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '6scm', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.866, 'start': 2, 'end': 487, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '7avt', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.88, 'start': 2, 'end': 487, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '7avt', 'chain_id': 'B', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.88, 'start': 2, 'end': 487, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '8be2', 'chain_id': 'S', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.89793505929, 'start': 22, 'end': 507, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '8be4', 'chain_id': 'S', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.9, 'start': 22, 'end': 507, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '6sfr', 'chain_id': 'A', 'experimental_method': 'X-ray diffraction', 'tax_id': 9606, 'coverage': 0.365, 'resolution': 1.917, 'start': 2, 'end': 487, 'unp_start': 564, 'unp_end': 1049}, {'pdb_id': '6sfr', 'chain_id': 'B', 'experimental_method': 'X-ray diffraction', 't ...

# %%
import pandas as pd
import numpy as np
SOS1_json = pd.read_json('/content/drive/MyDrive/InterviewExercise/SOS1.json')
SOS1_json.head()
# save to csv
SOS1_csv = '/content/drive/MyDrive/InterviewExercise/SOS1.csv'
SOS1_json.to_csv(SOS1_csv, index='pdb_id')
SOS1_csv_df = pd.read_csv(SOS1_csv)
SOS1_json.head()
# Out:
#                                               Q07889
# 0  {'pdb_id': '3ksy', 'chain_id': 'A', 'experimen...
# 1  {'pdb_id': '1xd4', 'chain_id': 'A', 'experimen...
# 2  {'pdb_id': '1xd4', 'chain_id': 'B', 'experimen...
# 3  {'pdb_id': '1xdv', 'chain_id': 'A', 'experimen...
# 4  {'pdb_id': '1xdv', 'chain_id': 'B', 'experimen...

# %% [markdown]
# The above dataframe does not look proper!!

# %%
import json # import json

# %%
with open ('/content/drive/MyDrive/InterviewExercise/SOS1.json') as jf:
  data = json.load(jf)

# %%
data.keys()
# Out:
# dict_keys(['Q07889'])

# %%
# data.values() # this code prints all the values in Q07889

# %%
df = pd.json_normalize(data, record_path="Q07889") # this normalises the list of dictionaries to a proper csv DataFrame
df
# Out:
#     pdb_id chain_id experimental_method  tax_id  coverage  resolution  start  \
# 0     3ksy        A   X-ray diffraction    9606     0.787       3.178      1
# 1     1xd4        A   X-ray diffraction    9606     0.639       3.640      1
# 2     1xd4        B   X-ray diffraction    9606     0.639       3.640      1
# 3     1xdv        A   X-ray diffraction    9606     0.635       4.100      1
# 4     1xdv        B   X-ray diffraction    9606     0.635       4.100      1
# ..     ...      ...                 ...     ...       ...         ...    ...
# 103   6y44        P   X-ray diffraction    9606     0.010       1.710      1
# 104   6f08        D   X-ray diffraction    9606     0.010       1.900      1
# 105   6f08        K   X-ray diffraction    9606     0.010       1.900      1
# 106   6f08        N   X-ray diffraction    9606     0.010       1.900      1
# 107   6f08        Q   X-ray diffraction    9606     0.010       1.900      1
#
#       end  unp_start  unp_end
# 0    1049          1     1049
# 1     852        198     1049
# 2     852        198     1049
# 3     847        198     1044
# 4     847        198     1044
# ..    ...        ...      ...
# 103    13       1155     1167
# 104    13       1155     1167
# 105    13       1155     1167
# 106    13       1155     1167
# 107    13       1155     1167
#
# [108 rows x 10 columns]

# %%
df['pdb_id'] # PDB Entries associated with SOS1 Q07889
# Out:
# 0      3ksy
# 1      1xd4
# 2      1xd4
# 3      1xdv
# 4      1xdv
#        ...
# 103    6y44
# 104    6f08
# 105    6f08
# 106    6f08
# 107    6f08
# Name: pdb_id, Length: 108, dtype: object

# %%
# !pip install rdkit-pypi # instal rdkit
# Out:
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 34.5 MB/s eta 0:00:00
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5

# %% [markdown]
# **Extract the co-crystalized Ligands**

# %%
# Step 1: Get PDB IDs associated with the protein (using UniProt ID)
uniprot_id = 'Q07889'  # Example: SOS1 protein
url = f"https://www.ebi.ac.uk/pdbe/api/mappings/best_structures/{uniprot_id}"

try:
    response = requests.get(url)
    response.raise_for_status()  # this checks for HTTP errors
    data = response.json()

    # Extract PDB IDs
    pdb_ids = [entry['pdb_id'] for entry in data.get(uniprot_id, [])]

    if not pdb_ids:
        print("No PDB IDs found for this UniProt ID.")
    else:
        # Step 2: For each PDB ID, retrieve ligand information including SMILES
        for pdb_id in pdb_ids:
            ligand_url = f'https://www.ebi.ac.uk/pdbe/api/pdb/entry/ligand_monomers/{pdb_id}'

            ligands_response = requests.get(ligand_url)

            if ligands_response.status_code == 200:
                ligands_data = ligands_response.json()

                if pdb_id in ligands_data:
                    print(f"PDB ID: {pdb_id}")
                    for ligand in ligands_data[pdb_id]:
                        print(f"Ligand ID (HET code): {ligand['chem_comp_id']}")
                        print(f"Ligand Name: {ligand['chem_comp_name']}")

                        # Print the entire ligand dictionary to understand its structure
                        print("Ligand Dictionary:", ligand)
                        # Print the keys of the dictionary to see if 'smiles' is present
                        print("Keys in Ligand Dictionary:", ligand.keys())
                        # Check if 'smiles' key is in the ligand dictionary
                        if 'smiles' in ligand:
                          smiles = ligand['smiles']
                          if smiles:
                            print(f"SMILES: {smiles}")
                          else:
                            print("SMILES information is present but empty.")
                        else:
                          print("SMILES information is not available in the ligand.")

                        dataset = print()
                else:
                    print(f"No ligands found for PDB ID: {pdb_id}")
            else:
                print(f"Error retrieving ligands for PDB ID: {pdb_id} - Status Code: {ligands_response.status_code}")
            print("-" * 40)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# PDB ID: 3ksy
# ----------------------------------------
# PDB ID: 1xd4
# ----------------------------------------
# PDB ID: 1xd4
# ----------------------------------------
# PDB ID: 1xdv
# ----------------------------------------
# PDB ID: 1xdv
# ----------------------------------------
# PDB ID: 8xjj
# Ligand ID (HET code): A1LVJ
# Ligand Name: 5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-fluoranyl-phenyl]ethyl]amino]-2-methyl-6-morpholin-4-yl-7-oxidanylidene-pyrido[4,3-d]pyrimidin-8-yl]pyridine-2-carbonitrile
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1201, 'author_insertion_code': '', 'chem_comp_id': 'A1LVJ', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-fluoranyl-phenyl]ethyl]amino]-2-methyl-6-morpholin-4-yl-7-oxidanylidene-pyrido[4,3-d]pyrimidin-8-yl]pyridine-2-carbonitrile', 'weight': 535.52, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1202, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1203, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1204, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1205, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1206, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'G', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1207, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'H', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1208, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1209, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'J', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1210, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'K', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1211, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'L', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1212, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'M', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1213, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'N', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 5ove
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): AXE
# Ligand Name: 6,7-dimethoxy-~{N}-[(1~{R})-1-naphthalen-1-ylethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'AXE', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-~{N}-[(1~{R})-1-naphthalen-1-ylethyl]quinazolin-4-amine', 'weight': 359.421, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 5ovd
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1105, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 5ovf
# Ligand ID (HET code): AWT
# Ligand Name: 6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(1~{H}-pyrazol-4-yl)phenyl]ethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'AWT', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(1~{H}-pyrazol-4-yl)phenyl]ethyl]quinazolin-4-amine', 'weight': 389.45, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 5ovi
# Ligand ID (HET code): AXH
# Ligand Name: 6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[4-[2-(methylaminomethyl)phenyl]thiophen-2-yl]ethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 2001, 'author_insertion_code': '', 'chem_comp_id': 'AXH', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[4-[2-(methylaminomethyl)phenyl]thiophen-2-yl]ethyl]quinazolin-4-amine', 'weight': 448.58, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 2002, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 2003, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 2004, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 5ovg
# Ligand ID (HET code): AWZ
# Ligand Name: ~{N}-[(1~{R})-1-[5-(6,7-dihydro-5~{H}-pyrrolo[1,2-a]imidazol-3-yl)thiophen-2-yl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'AWZ', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '~{N}-[(1~{R})-1-[5-(6,7-dihydro-5~{H}-pyrrolo[1,2-a]imidazol-3-yl)thiophen-2-yl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine', 'weight': 435.542, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 5ovh
# Ligand ID (HET code): AWW
# Ligand Name: [2-[5-[(1~{R})-1-[(6,7-dimethoxy-2-methyl-5,8-dihydroquinazolin-4-yl)amino]ethyl]thiophen-2-yl]phenyl]methanol
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'AWW', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': '[2-[5-[(1~{R})-1-[(6,7-dimethoxy-2-methyl-5,8-dihydroquinazolin-4-yl)amino]ethyl]thiophen-2-yl]phenyl]methanol', 'weight': 437.554, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 7avl
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'H', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'J', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): S2Z
# Ligand Name: 6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1105, 'author_insertion_code': '', 'chem_comp_id': 'S2Z', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'G', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine', 'weight': 323.389, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): S2Z
# Ligand Name: 6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'S2Z', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'K', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine', 'weight': 323.389, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 7avl
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'H', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'J', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): S2Z
# Ligand Name: 6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1105, 'author_insertion_code': '', 'chem_comp_id': 'S2Z', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'G', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine', 'weight': 323.389, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): S2Z
# Ligand Name: 6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'S2Z', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'K', 'residue_number': 1, 'chem_comp_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine', 'weight': 323.389, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 6scm
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'B', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1104, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1105, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1106, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'G', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): EDO
# Ligand Name: 1,2-ETHANEDIOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1107, 'author_insertion_code': '', 'chem_comp_id': 'EDO', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'H', 'residue_number': 1, 'chem_comp_name': '1,2-ETHANEDIOL', 'weight': 62.068, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): L7H
# Ligand Name: ~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-7-methoxy-2-methyl-6-[(3~{S})-oxolan-3-yl]oxy-quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1108, 'author_insertion_code': '', 'chem_comp_id': 'L7H', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-7-methoxy-2-methyl-6-[(3~{S})-oxolan-3-yl]oxy-quinazolin-4-amine', 'weight': 462.465, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 7avt
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1102, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'G', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): S3T
# Ligand Name: ~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'S3T', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': '~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine', 'weight': 338.404, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): S3T
# Ligand Name: ~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine
# Ligand Dictionary: {'chain_id': 'B', 'author_residue_number': 1103, 'author_insertion_code': '', 'chem_comp_id': 'S3T', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'H', 'residue_number': 1, 'chem_comp_name': '~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine', 'weight': 338.404, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 7avt
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'IMD', 'alternate_conformers': 0, 'entity_id': 2, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': 'IMIDAZOLE', 'weight': 69.085, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): IMD
# Ligand Name: IMIDAZOLE
# ...
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 4nyi
# Ligand ID (HET code): MG
# Ligand Name: MAGNESIUM ION
# Ligand Dictionary: {'chain_id': 'Q', 'author_residue_number': 201, 'author_insertion_code': '', 'chem_comp_id': 'MG', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'MAGNESIUM ION', 'weight': 24.305, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): GNP
# Ligand Name: PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER
# Ligand Dictionary: {'chain_id': 'Q', 'author_residue_number': 202, 'author_insertion_code': '', 'chem_comp_id': 'GNP', 'alternate_conformers': 0, 'entity_id': 5, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER', 'weight': 522.196, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): 2PX
# Ligand Name: N-{1-[(5-methyl-1H-indol-3-yl)methyl]piperidin-4-yl}-L-tryptophanamide
# Ligand Dictionary: {'chain_id': 'S', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': '2PX', 'alternate_conformers': 0, 'entity_id': 6, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'N-{1-[(5-methyl-1H-indol-3-yl)methyl]piperidin-4-yl}-L-tryptophanamide', 'weight': 429.557, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 1nvx
# Ligand ID (HET code): MG
# Ligand Name: MAGNESIUM ION
# Ligand Dictionary: {'chain_id': 'Q', 'author_residue_number': 1002, 'author_insertion_code': '', 'chem_comp_id': 'MG', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'MAGNESIUM ION', 'weight': 24.305, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): GTP
# Ligand Name: GUANOSINE-5'-TRIPHOSPHATE
# Ligand Dictionary: {'chain_id': 'Q', 'author_residue_number': 1001, 'author_insertion_code': '', 'chem_comp_id': 'GTP', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': "GUANOSINE-5'-TRIPHOSPHATE", 'weight': 523.18, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): PO4
# Ligand Name: PHOSPHATE ION
# Ligand Dictionary: {'chain_id': 'R', 'author_residue_number': 1003, 'author_insertion_code': '', 'chem_comp_id': 'PO4', 'alternate_conformers': 0, 'entity_id': 5, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'PHOSPHATE ION', 'weight': 94.971, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 4nym
# Ligand ID (HET code): MG
# Ligand Name: MAGNESIUM ION
# Ligand Dictionary: {'chain_id': 'Q', 'author_residue_number': 201, 'author_insertion_code': '', 'chem_comp_id': 'MG', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'MAGNESIUM ION', 'weight': 24.305, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): GNP
# Ligand Name: PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER
# Ligand Dictionary: {'chain_id': 'Q', 'author_residue_number': 202, 'author_insertion_code': '', 'chem_comp_id': 'GNP', 'alternate_conformers': 0, 'entity_id': 5, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER', 'weight': 522.196, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): RND
# Ligand Name: N-[1-(1H-indol-3-ylmethyl)piperidin-4-yl]-L-tryptophanamide
# Ligand Dictionary: {'chain_id': 'S', 'author_residue_number': 1101, 'author_insertion_code': '', 'chem_comp_id': 'RND', 'alternate_conformers': 0, 'entity_id': 6, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'N-[1-(1H-indol-3-ylmethyl)piperidin-4-yl]-L-tryptophanamide', 'weight': 415.531, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 1bkd
# ----------------------------------------
# PDB ID: 1dbh
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1q9c
# ----------------------------------------
# PDB ID: 1awe
# ----------------------------------------
# PDB ID: 6y44
# Ligand ID (HET code): MG
# Ligand Name: MAGNESIUM ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 301, 'author_insertion_code': '', 'chem_comp_id': 'MG', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'C', 'residue_number': 1, 'chem_comp_name': 'MAGNESIUM ION', 'weight': 24.305, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): MG
# Ligand Name: MAGNESIUM ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 302, 'author_insertion_code': '', 'chem_comp_id': 'MG', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'D', 'residue_number': 1, 'chem_comp_name': 'MAGNESIUM ION', 'weight': 24.305, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): MG
# Ligand Name: MAGNESIUM ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 308, 'author_insertion_code': '', 'chem_comp_id': 'MG', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'J', 'residue_number': 1, 'chem_comp_name': 'MAGNESIUM ION', 'weight': 24.305, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): CL
# Ligand Name: CHLORIDE ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 303, 'author_insertion_code': '', 'chem_comp_id': 'CL', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'E', 'residue_number': 1, 'chem_comp_name': 'CHLORIDE ION', 'weight': 35.453, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): CL
# Ligand Name: CHLORIDE ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 304, 'author_insertion_code': '', 'chem_comp_id': 'CL', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'F', 'residue_number': 1, 'chem_comp_name': 'CHLORIDE ION', 'weight': 35.453, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): CL
# Ligand Name: CHLORIDE ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 305, 'author_insertion_code': '', 'chem_comp_id': 'CL', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'G', 'residue_number': 1, 'chem_comp_name': 'CHLORIDE ION', 'weight': 35.453, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): CL
# Ligand Name: CHLORIDE ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 306, 'author_insertion_code': '', 'chem_comp_id': 'CL', 'alternate_conformers': 0, 'entity_id': 4, 'struct_asym_id': 'H', 'residue_number': 1, 'chem_comp_name': 'CHLORIDE ION', 'weight': 35.453, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# Ligand ID (HET code): CA
# Ligand Name: CALCIUM ION
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 307, 'author_insertion_code': '', 'chem_comp_id': 'CA', 'alternate_conformers': 0, 'entity_id': 5, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'CALCIUM ION', 'weight': 40.078, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 6f08
# Ligand ID (HET code): 1PE
# Ligand Name: PENTAETHYLENE GLYCOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 301, 'author_insertion_code': '', 'chem_comp_id': '1PE', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'PENTAETHYLENE GLYCOL', 'weight': 238.278, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 6f08
# Ligand ID (HET code): 1PE
# Ligand Name: PENTAETHYLENE GLYCOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 301, 'author_insertion_code': '', 'chem_comp_id': '1PE', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'PENTAETHYLENE GLYCOL', 'weight': 238.278, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 6f08
# Ligand ID (HET code): 1PE
# Ligand Name: PENTAETHYLENE GLYCOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 301, 'author_insertion_code': '', 'chem_comp_id': '1PE', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'PENTAETHYLENE GLYCOL', 'weight': 238.278, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------
# PDB ID: 6f08
# Ligand ID (HET code): 1PE
# Ligand Name: PENTAETHYLENE GLYCOL
# Ligand Dictionary: {'chain_id': 'A', 'author_residue_number': 301, 'author_insertion_code': '', 'chem_comp_id': '1PE', 'alternate_conformers': 0, 'entity_id': 3, 'struct_asym_id': 'I', 'residue_number': 1, 'chem_comp_name': 'PENTAETHYLENE GLYCOL', 'weight': 238.278, 'carbohydrate_polymer': False, 'branch_name': ''}
# Keys in Ligand Dictionary: dict_keys(['chain_id', 'author_residue_number', 'author_insertion_code', 'chem_comp_id', 'alternate_conformers', 'entity_id', 'struct_asym_id', 'residue_number', 'chem_comp_name', 'weight', 'carbohydrate_polymer', 'branch_name'])
# SMILES information is not available in the ligand.
#
# ----------------------------------------

# %%
import json
import requests
import urllib
from urllib.request import urlopen
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

# Step 1: Get PDB IDs associated with the protein (using UniProt ID)
uniprot_id = 'Q07889'
url = f"https://www.ebi.ac.uk/pdbe/api/mappings/best_structures/{uniprot_id}"

all_ligand_data = []  # Initialize a list to store all ligand data

try:
    response = requests.get(url)
    response.raise_for_status()
    data = response.json()

    # Extract PDB IDs
    pdb_ids = [entry['pdb_id'] for entry in data.get(uniprot_id, [])]

    if not pdb_ids:
        print("No PDB IDs found for this UniProt ID.")
    else:
        # Step 2: For each PDB ID, retrieve ligand information including SMILES
        for pdb_id in pdb_ids:
            ligand_url = f'https://www.ebi.ac.uk/pdbe/api/pdb/entry/ligand_monomers/{pdb_id}'

            ligands_response = requests.get(ligand_url)

            if ligands_response.status_code == 200:
                ligands_data = ligands_response.json()

                if pdb_id in ligands_data:
                    for ligand in ligands_data[pdb_id]:
                        ligand_info = {
                            'pdb_id': pdb_id,
                            'ligand_id': ligand['chem_comp_id'],
                            'ligand_name': ligand['chem_comp_name'],
                            'smiles': ligand.get('smiles', '')  # Extract smiles
                        }
                        all_ligand_data.append(ligand_info)
                else:
                    print(f"No ligands found for PDB ID: {pdb_id}")
            else:
                print(f"Error retrieving ligands for PDB ID: {pdb_id} - Status Code: {ligands_response.status_code}")
            print("-" * 40)

except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")

# present in dataframe
df = pd.DataFrame(all_ligand_data)

# Save the DataFrame to a JSON file
output_json_file = 'ligand_data.json'
df.to_json(output_json_file, orient='records')

print(f"Ligand data saved to: {output_json_file}")
# Out:
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# Ligand data saved to: ligand_data.json

# %% [markdown]
# **Did not verbose, but its printed already, I can call this or put in DataFrame for visualization**

# %%
all_ligand_data
# Out:
# [{'pdb_id': '8xjj',
#   'ligand_id': 'A1LVJ',
#   'ligand_name': '5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-fluoranyl-phenyl]ethyl]amino]-2-methyl-6-morpholin-4-yl-7-oxidanylidene-pyrido[4,3-d]pyrimidin-8-yl]pyridine-2-carbonitrile',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '8xjj',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ove',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ove',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ove',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ove',
#   'ligand_id': 'AXE',
#   'ligand_name': '6,7-dimethoxy-~{N}-[(1~{R})-1-naphthalen-1-ylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '5ovd',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovd',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovd',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovd',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovd',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovf',
#   'ligand_id': 'AWT',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(1~{H}-pyrazol-4-yl)phenyl]ethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '5ovf',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovi',
#   'ligand_id': 'AXH',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[4-[2-(methylaminomethyl)phenyl]thiophen-2-yl]ethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '5ovi',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovi',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovi',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovg',
#   'ligand_id': 'AWZ',
#   'ligand_name': '~{N}-[(1~{R})-1-[5-(6,7-dihydro-5~{H}-pyrrolo[1,2-a]imidazol-3-yl)thiophen-2-yl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '5ovg',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovg',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovh',
#   'ligand_id': 'AWW',
#   'ligand_name': '[2-[5-[(1~{R})-1-[(6,7-dimethoxy-2-methyl-5,8-dihydroquinazolin-4-yl)amino]ethyl]thiophen-2-yl]phenyl]methanol',
#   'smiles': ''},
#  {'pdb_id': '5ovh',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '5ovh',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'S2Z',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'S2Z',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'S2Z',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avl',
#   'ligand_id': 'S2Z',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'EDO',
#   'ligand_name': '1,2-ETHANEDIOL',
#   'smiles': ''},
#  {'pdb_id': '6scm',
#   'ligand_id': 'L7H',
#   'ligand_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-7-methoxy-2-methyl-6-[(3~{S})-oxolan-3-yl]oxy-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'S3T',
#   'ligand_name': '~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'S3T',
#   'ligand_name': '~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'S3T',
#   'ligand_name': '~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avt',
#   'ligand_id': 'S3T',
#   'ligand_name': '~{N}-[(1~{R})-1-(3-aminophenyl)ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '8be2',
#   'ligand_id': 'SO4',
#   'ligand_name': 'SULFATE ION',
#   'smiles': ''},
#  {'pdb_id': '8be2',
#   'ligand_id': 'SO4',
#   'ligand_name': 'SULFATE ION',
#   'smiles': ''},
#  {'pdb_id': '8be2',
#   'ligand_id': 'SO4',
#   'ligand_name': 'SULFATE ION',
#   'smiles': ''},
#  {'pdb_id': '8be2',
#   'ligand_id': 'SO4',
#   'ligand_name': 'SULFATE ION',
#   'smiles': ''},
#  {'pdb_id': '8be2',
#   'ligand_id': 'SO4',
#   'ligand_name': 'SULFATE ION',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'LBK',
#   'ligand_name': '6,7-dimethoxy-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'LBK',
#   'ligand_name': '6,7-dimethoxy-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'LBK',
#   'ligand_name': '6,7-dimethoxy-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '6sfr',
#   'ligand_id': 'LBK',
#   'ligand_name': '6,7-dimethoxy-~{N}-[(1~{R})-1-phenylethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avi',
#   'ligand_id': 'S2Q',
#   'ligand_name': '3-propan-2-yl-~{N}-[(1~{R})-1-(3-sulfamoylphenyl)ethyl]-[1,2]oxazolo[5,4-b]pyridine-5-carboxamide',
#   'smiles': ''},
#  {'pdb_id': '7avi',
#   'ligand_id': 'S2Q',
#   'ligand_name': '3-propan-2-yl-~{N}-[(1~{R})-1-(3-sulfamoylphenyl)ethyl]-[1,2]oxazolo[5,4-b]pyridine-5-carboxamide',
#   'smiles': ''},
#  {'pdb_id': '7avi',
#   'ligand_id': 'S2Q',
#   'ligand_name': '3-propan-2-yl-~{N}-[(1~{R})-1-(3-sulfamoylphenyl)ethyl]-[1,2]oxazolo[5,4-b]pyridine-5-carboxamide',
#   'smiles': ''},
#  {'pdb_id': '7avi',
#   'ligand_id': 'S2Q',
#   'ligand_name': '3-propan-2-yl-~{N}-[(1~{R})-1-(3-sulfamoylphenyl)ethyl]-[1,2]oxazolo[5,4-b]pyridine-5-carboxamide',
#   'smiles': ''},
#  {'pdb_id': '7avu',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avu',
#   'ligand_id': 'S3Z',
#   'ligand_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avu',
#   'ligand_id': 'S3Z',
#   'ligand_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avu',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avu',
#   'ligand_id': 'S3Z',
#   'ligand_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avu',
#   'ligand_id': 'S3Z',
#   'ligand_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-6,7-dimethoxy-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avv',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avv',
#   'ligand_id': 'S2W',
#   'ligand_name': '~{N}-[(1~{R})-1-[3-azanyl-5-(trifluoromethyl)phenyl]ethyl]-2-methyl-quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '4us0',
#   'ligand_id': 'NEN',
#   'ligand_name': '1-ETHYL-PYRROLIDINE-2,5-DIONE',
#   'smiles': ''},
#  {'pdb_id': '4urz',
#   'ligand_id': 'VJP',
#   'ligand_name': '1-[(4-aminophenyl)sulfonyl]piperidin-2-one',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'S3Q',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(trifluoromethyl)phenyl]ethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'S3Q',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(trifluoromethyl)phenyl]ethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'IMD',
#   'ligand_name': 'IMIDAZOLE',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'S3Q',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(trifluoromethyl)phenyl]ethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7avs',
#   'ligand_id': 'S3Q',
#   'ligand_name': '6,7-dimethoxy-2-methyl-~{N}-[(1~{R})-1-[3-(trifluoromethyl)phenyl]ethyl]quinazolin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '7uks',
#   'ligand_id': 'NL0',
#   'ligand_name': '4-methyl-N-{(1R)-1-[2-methyl-3-(trifluoromethyl)phenyl]ethyl}-7-(piperazin-1-yl)phthalazin-1-amine',
#   'smiles': ''},
#  {'pdb_id': '6epo',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6epo',
#   'ligand_id': 'BPW',
#   'ligand_name': '3-(4-chlorophenyl)propan-1-amine',
#   'smiles': ''},
#  {'pdb_id': '6epo',
#   'ligand_id': 'BPW',
#   'ligand_name': '3-(4-chlorophenyl)propan-1-amine',
#   'smiles': ''},
#  {'pdb_id': '6epp',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6epp',
#   'ligand_id': 'BOQ',
#   'ligand_name': 'ethyl 2-(aminomethyl)-5-~{tert}-butyl-furan-3-carboxylate',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be8',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '4ury',
#   'ligand_id': 'RV1',
#   'ligand_name': 'N-[(4-aminophenyl)sulfonyl]cyclopropanecarboxamide',
#   'smiles': ''},
#  {'pdb_id': '4ury',
#   'ligand_id': 'RV1',
#   'ligand_name': 'N-[(4-aminophenyl)sulfonyl]cyclopropanecarboxamide',
#   'smiles': ''},
#  {'pdb_id': '4us2',
#   'ligand_id': 'L7S',
#   'ligand_name': '3-[(3R)-1-ethyl-2,5-dioxopyrrolidin-3-yl]benzamide',
#   'smiles': ''},
#  {'pdb_id': '4urx',
#   'ligand_id': 'FK1',
#   'ligand_name': '6-bromo-1H-indole',
#   'smiles': ''},
#  {'pdb_id': '4urx',
#   'ligand_id': 'HXY',
#   'ligand_name': '1-(4-bromobenzyl)pyrrolidine',
#   'smiles': ''},
#  {'pdb_id': '4urx',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6epm',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6epm',
#   'ligand_id': 'BQ5',
#   'ligand_name': '(1-phenyl-5,6-dihydro-4~{H}-cyclopenta[c]pyrazol-3-yl)methanamine',
#   'smiles': ''},
#  {'pdb_id': '6epn',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6epn',
#   'ligand_id': 'BQ2',
#   'ligand_name': '1-(3,4-dihydro-1~{H}-isoquinolin-2-yl)-2-oxidanyl-ethanone',
#   'smiles': ''},
#  {'pdb_id': '6epn',
#   'ligand_id': 'DMS',
#   'ligand_name': 'DIMETHYL SULFOXIDE',
#   'smiles': ''},
#  {'pdb_id': '7ukr',
#   'ligand_id': 'NKF',
#   'ligand_name': '2-methyl-3-[(1R)-1-{[4-methyl-7-(morpholin-4-yl)pyrido[3,4-d]pyridazin-1-yl]amino}ethyl]benzonitrile',
#   'smiles': ''},
#  {'pdb_id': '7ukr',
#   'ligand_id': 'NKF',
#   'ligand_name': '2-methyl-3-[(1R)-1-{[4-methyl-7-(morpholin-4-yl)pyrido[3,4-d]pyridazin-1-yl]amino}ethyl]benzonitrile',
#   'smiles': ''},
#  {'pdb_id': '7ukr',
#   'ligand_id': 'NKF',
#   'ligand_name': '2-methyl-3-[(1R)-1-{[4-methyl-7-(morpholin-4-yl)pyrido[3,4-d]pyridazin-1-yl]amino}ethyl]benzonitrile',
#   'smiles': ''},
#  {'pdb_id': '7ukr',
#   'ligand_id': 'NKF',
#   'ligand_name': '2-methyl-3-[(1R)-1-{[4-methyl-7-(morpholin-4-yl)pyrido[3,4-d]pyridazin-1-yl]amino}ethyl]benzonitrile',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '8be9',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6epl',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '4urv',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '4urv',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '4urv',
#   'ligand_id': 'UMK',
#   'ligand_name': '4-(4-BROMOPHENYL)PIPERIDIN-4-OL',
#   'smiles': ''},
#  {'pdb_id': '4us1',
#   'ligand_id': 'L71',
#   'ligand_name': '(3S)-3-[3-(aminomethyl)phenyl]-1-ethylpyrrolidine-2,5-dione',
#   'smiles': ''},
#  {'pdb_id': '4urw',
#   'ligand_id': 'DXO',
#   'ligand_name': '2-(2,6-DIMETHYLPHENYL)-4-(METHYLSULFANYL)-6-(PIPERAZIN-1-YL)-1,3,5-TRIAZINE',
#   'smiles': ''},
#  {'pdb_id': '4uru',
#   'ligand_id': '6W2',
#   'ligand_name': '4-METHOXY-N-(1,3-THIAZOL-2-YL)BENZENESULFONAMIDE',
#   'smiles': ''},
#  {'pdb_id': '7kfz',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '7kfz',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '1xd2',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '1xd2',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1xd2',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1xd2',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1xd2',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1xd2',
#   'ligand_id': 'GDP',
#   'ligand_name': "GUANOSINE-5'-DIPHOSPHATE",
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'QTG',
#   'ligand_name': '4-fluoro-2-methyl-N-propylbenzene-1-sulfonamide',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9m',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'QTD',
#   'ligand_name': '4-phenoxybenzene-1-sulfonamide',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9n',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FWA',
#   'ligand_name': '6-chloro-2-(2,6-diazaspiro[3.3]heptan-2-yl)-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-4-(4-methylpiperazin-1-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d55',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FVM',
#   'ligand_name': '6-chloro-2-(2,6-diazaspiro[3.3]heptan-2-yl)-4-(3,5-dimethyl-1H-pyrazol-4-yl)-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d56',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'ACT',
#   'ligand_name': 'ACETATE ION',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'QTJ',
#   'ligand_name': '4-(3-chloro-4-fluorophenoxy)benzene-1-sulfonamide',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9l',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FVJ',
#   'ligand_name': '6-chloro-4-(3,5-dimethyl-1H-pyrazol-4-yl)-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-2-(piperazin-1-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d59',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'FW7',
#   'ligand_name': '6-chloro-1-[(3-chloro-4-fluorophenyl)methyl]-2-(piperazin-1-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5l',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'FFS',
#   'ligand_name': 'N~2~-(3-chlorophenyl)-N~4~-[(furan-2-yl)methyl]quinazoline-2,4-diamine',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6cuo',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FFY',
#   'ligand_name': 'N~2~-(3-chloro-4-fluorophenyl)-N~4~-[(1R)-1-cyclopropylethyl]-8-(1,2,3,6-tetrahydropyridin-4-yl)quinazoline-2,4-diamine',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6cur',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'EC4',
#   'ligand_name': '6-chloro-N-{1-[(5-chloro-1H-indol-3-yl)methyl]piperidin-4-yl}-L-tryptophanamide',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvi',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'EAS',
#   'ligand_name': '5-chloro-N-{1-[(5-chloro-1H-indol-3-yl)methyl]piperidin-4-yl}-L-tryptophanamide',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvj',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'EBY',
#   'ligand_name': 'N-{1-[(5-chloro-1H-indol-3-yl)methyl]piperidin-4-yl}-5-methyl-L-tryptophanamide',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvl',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FVG',
#   'ligand_name': '1-[(2S)-1-{6-chloro-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-2-(piperazin-1-yl)-1H-benzimidazol-4-yl}pyrrolidin-2-yl]methanamine',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5e',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FV4',
#   'ligand_name': '6-chloro-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-2-(piperazin-1-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5j',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'QTM',
#   'ligand_name': '3-(2-aminoethyl)-4-(3-chloro-4-fluorophenoxy)benzene-1-sulfonamide',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9j',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'EBV',
#   'ligand_name': '(2S)-2-amino-1-[(3aR,6aS)-5-[(5-chloro-1H-indol-3-yl)methyl]hexahydropyrrolo[3,4-c]pyrrol-2(1H)-yl]-3-(1H-indol-3-yl)propan-1-one',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvm',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'EAV',
#   'ligand_name': 'N-{1-[(5-chloro-1H-indol-3-yl)methyl]piperidin-4-yl}-6-methyl-L-tryptophanamide',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6bvk',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'QTA',
#   'ligand_name': '3-(phenylsulfonyl)benzene-1-sulfonamide',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'QTA',
#   'ligand_name': '3-(phenylsulfonyl)benzene-1-sulfonamide',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9o',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'FV7',
#   'ligand_name': '6-chloro-4-(2-chlorophenyl)-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-2-(piperazin-1-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5h',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'QTV',
#   'ligand_name': '1-[(4-fluorophenyl)methyl]-2-methyl-4-nitro-1H-imidazole',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v94',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FFV',
#   'ligand_name': 'N~2~-(3-chloro-4-fluorophenyl)-N~4~-[(1R)-1-cyclopropylethyl]quinazoline-2,4-diamine',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6cup',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'QTS',
#   'ligand_name': '1-[(4-chlorophenyl)methyl]-1H-benzimidazol-2-amine',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6v9f',
#   'ligand_id': 'NA',
#   'ligand_name': 'SODIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FMT',
#   'ligand_name': 'FORMIC ACID',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'FVD',
#   'ligand_name': '6-chloro-1-[(4-fluoro-3,5-dimethylphenyl)methyl]-2-(piperazin-1-yl)-4-(1,2,3,6-tetrahydropyridin-4-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'GOL',
#   'ligand_name': 'GLYCEROL',
#   'smiles': ''},
#  {'pdb_id': '6d5g',
#   'ligand_id': 'BME',
#   'ligand_name': 'BETA-MERCAPTOETHANOL',
#   'smiles': ''},
#  {'pdb_id': '5wfo',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '5wfo',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '5wfo',
#   'ligand_id': '5UU',
#   'ligand_name': '6-chloranyl-~{N}-(4-fluorophenyl)-1,2,3,4-tetrahydroacridin-9-amine',
#   'smiles': ''},
#  {'pdb_id': '6d5v',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5v',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5v',
#   'ligand_id': 'FVY',
#   'ligand_name': '1-[(3-chloro-4-fluorophenyl)methyl]-5,6-dimethyl-1H-benzimidazol-2-amine',
#   'smiles': ''},
#  {'pdb_id': '5wfp',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '5wfp',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '5wfp',
#   'ligand_id': '5UX',
#   'ligand_name': '6-chloranyl-~{N}-(3-chloranyl-4-fluoranyl-phenyl)-1,2,3,4-tetrahydroacridin-9-amine',
#   'smiles': ''},
#  {'pdb_id': '6d5m',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5m',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5m',
#   'ligand_id': 'FW4',
#   'ligand_name': '1-[(3-chloro-4-fluorophenyl)methyl]-5,6-dimethyl-2-(piperazin-1-yl)-1H-benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvv',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvu',
#   'ligand_id': 'GTP',
#   'ligand_name': "GUANOSINE-5'-TRIPHOSPHATE",
#   'smiles': ''},
#  {'pdb_id': '5wfq',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '5wfq',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '5wfq',
#   'ligand_id': '5UV',
#   'ligand_name': '7-chloranyl-~{N}-(3-chloranyl-4-fluoranyl-phenyl)-1,2,3,4-tetrahydroacridin-9-amine',
#   'smiles': ''},
#  {'pdb_id': '5wfr',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '5wfr',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '5wfr',
#   'ligand_id': '5UW',
#   'ligand_name': '~{N}-(3,3-diphenylpropyl)piperidin-4-amine',
#   'smiles': ''},
#  {'pdb_id': '6d5w',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6d5w',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '6d5w',
#   'ligand_id': 'FVV',
#   'ligand_name': '10-[(4-fluorophenyl)methyl]-2,3,4,10-tetrahydropyrimido[1,2-a]benzimidazole',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '1nvw',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '4nyj',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '4nyj',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '4nyj',
#   'ligand_id': '2PZ',
#   'ligand_name': 'N-[1-(1H-indol-3-ylmethyl)piperidin-4-yl]glycinamide',
#   'smiles': ''},
#  {'pdb_id': '4nyi',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '4nyi',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '4nyi',
#   'ligand_id': '2PX',
#   'ligand_name': 'N-{1-[(5-methyl-1H-indol-3-yl)methyl]piperidin-4-yl}-L-tryptophanamide',
#   'smiles': ''},
#  {'pdb_id': '1nvx',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '1nvx',
#   'ligand_id': 'GTP',
#   'ligand_name': "GUANOSINE-5'-TRIPHOSPHATE",
#   'smiles': ''},
#  {'pdb_id': '1nvx',
#   'ligand_id': 'PO4',
#   'ligand_name': 'PHOSPHATE ION',
#   'smiles': ''},
#  {'pdb_id': '4nym',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '4nym',
#   'ligand_id': 'GNP',
#   'ligand_name': 'PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ESTER',
#   'smiles': ''},
#  {'pdb_id': '4nym',
#   'ligand_id': 'RND',
#   'ligand_name': 'N-[1-(1H-indol-3-ylmethyl)piperidin-4-yl]-L-tryptophanamide',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'MG',
#   'ligand_name': 'MAGNESIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'CL',
#   'ligand_name': 'CHLORIDE ION',
#   'smiles': ''},
#  {'pdb_id': '6y44',
#   'ligand_id': 'CA',
#   'ligand_name': 'CALCIUM ION',
#   'smiles': ''},
#  {'pdb_id': '6f08',
#   'ligand_id': '1PE',
#   'ligand_name': 'PENTAETHYLENE GLYCOL',
#   'smiles': ''},
#  {'pdb_id': '6f08',
#   'ligand_id': '1PE',
#   'ligand_name': 'PENTAETHYLENE GLYCOL',
#   'smiles': ''},
#  {'pdb_id': '6f08',
#   'ligand_id': '1PE',
#   'ligand_name': 'PENTAETHYLENE GLYCOL',
#   'smiles': ''},
#  {'pdb_id': '6f08',
#   'ligand_id': '1PE',
#   'ligand_name': 'PENTAETHYLENE GLYCOL',
#   'smiles': ''}]

# %%
df2 = pd.DataFrame(all_ligand_data)
df2
# Out:
#     pdb_id ligand_id                                        ligand_name smiles
# 0     8xjj     A1LVJ  5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-f...
# 1     8xjj       EDO                                     1,2-ETHANEDIOL
# 2     8xjj       EDO                                     1,2-ETHANEDIOL
# 3     8xjj       EDO                                     1,2-ETHANEDIOL
# 4     8xjj       EDO                                     1,2-ETHANEDIOL
# ..     ...       ...                                                ...    ...
# 528   6y44        CA                                        CALCIUM ION
# 529   6f08       1PE                               PENTAETHYLENE GLYCOL
# 530   6f08       1PE                               PENTAETHYLENE GLYCOL
# 531   6f08       1PE                               PENTAETHYLENE GLYCOL
# 532   6f08       1PE                               PENTAETHYLENE GLYCOL
#
# [533 rows x 4 columns]

# %% [markdown]
# **here is it**

# %%
df2.set_index('pdb_id', inplace=True)
df2 = df.reset_index(drop=True)
df2
# Out:
#     pdb_id ligand_id                                        ligand_name smiles
# 0     8xjj     A1LVJ  5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-f...
# 1     8xjj       EDO                                     1,2-ETHANEDIOL
# 2     8xjj       EDO                                     1,2-ETHANEDIOL
# 3     8xjj       EDO                                     1,2-ETHANEDIOL
# 4     8xjj       EDO                                     1,2-ETHANEDIOL
# ..     ...       ...                                                ...    ...
# 528   6y44        CA                                        CALCIUM ION
# 529   6f08       1PE                               PENTAETHYLENE GLYCOL
# 530   6f08       1PE                               PENTAETHYLENE GLYCOL
# 531   6f08       1PE                               PENTAETHYLENE GLYCOL
# 532   6f08       1PE                               PENTAETHYLENE GLYCOL
#
# [533 rows x 4 columns]

# %%
df2 = df2.rename(columns={'pdb_id': 'PDBID', 'ligand_id': 'CODE', 'ligand_name': 'LIGAND_NAME'})
df2
# Out:
#     PDBID   CODE                                        LIGAND_NAME smiles
# 0    8xjj  A1LVJ  5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-f...
# 1    8xjj    EDO                                     1,2-ETHANEDIOL
# 2    8xjj    EDO                                     1,2-ETHANEDIOL
# 3    8xjj    EDO                                     1,2-ETHANEDIOL
# 4    8xjj    EDO                                     1,2-ETHANEDIOL
# ..    ...    ...                                                ...    ...
# 528  6y44     CA                                        CALCIUM ION
# 529  6f08    1PE                               PENTAETHYLENE GLYCOL
# 530  6f08    1PE                               PENTAETHYLENE GLYCOL
# 531  6f08    1PE                               PENTAETHYLENE GLYCOL
# 532  6f08    1PE                               PENTAETHYLENE GLYCOL
#
# [533 rows x 4 columns]

# %%
all_ligand_data = '/content/drive/MyDrive/InterviewExercise/all_ligand_data.csv' # save to drive directory

# %% [markdown]
# **To get the list of the SMILES of the assoiated Ligands, we need the pubchempy module**

# %%
# !pip install pubchempy # install pubchempy
# Out:
# Collecting pubchempy
#   Downloading PubChemPy-1.0.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pubchempy
#   Building wheel for pubchempy (setup.py) ... done
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13820 sha256=9ddc791b53bdd0fd340cef969d0927aef51992c219d82295868e2e941687b26e
#   Stored in directory: /root/.cache/pip/wheels/90/7c/45/18a0671e3c3316966ef7ed9ad2b3f3300a7e41d3421a44e799
# Successfully built pubchempy
# Installing collected packages: pubchempy
# Successfully installed pubchempy-1.0.4

# %%
ligands = df2['LIGAND_NAME']
ligands # view the co-crystalized ligands
# Out:
# 0      5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-f...
# 1                                         1,2-ETHANEDIOL
# 2                                         1,2-ETHANEDIOL
# 3                                         1,2-ETHANEDIOL
# 4                                         1,2-ETHANEDIOL
#                              ...
# 528                                          CALCIUM ION
# 529                                 PENTAETHYLENE GLYCOL
# 530                                 PENTAETHYLENE GLYCOL
# 531                                 PENTAETHYLENE GLYCOL
# 532                                 PENTAETHYLENE GLYCOL
# Name: LIGAND_NAME, Length: 533, dtype: object

# %% [markdown]
# **Get the SMILES here**

# %%
import pubchempy as pcp
def get_smiles(ligands):
    try:
        compound = pcp.get_compounds(ligands, 'name')
        if compound:
            return compound[0].canonical_smiles
        else:
            return None
    except Exception as e:
        return None

# Apply the function to each row in the DataFrame
df2['SMILES'] = df2['LIGAND_NAME'].apply(get_smiles)
df2
# Out:
#     PDBID   CODE                                        LIGAND_NAME smiles  \
# 0    8xjj  A1LVJ  5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-f...
# 1    8xjj    EDO                                     1,2-ETHANEDIOL
# 2    8xjj    EDO                                     1,2-ETHANEDIOL
# 3    8xjj    EDO                                     1,2-ETHANEDIOL
# 4    8xjj    EDO                                     1,2-ETHANEDIOL
# ..    ...    ...                                                ...    ...
# 528  6y44     CA                                        CALCIUM ION
# 529  6f08    1PE                               PENTAETHYLENE GLYCOL
# 530  6f08    1PE                               PENTAETHYLENE GLYCOL
# 531  6f08    1PE                               PENTAETHYLENE GLYCOL
# 532  6f08    1PE                               PENTAETHYLENE GLYCOL
#
#                  SMILES
# 0                  None
# 1                C(CO)O
# 2                C(CO)O
# 3                C(CO)O
# 4                C(CO)O
# ..                  ...
# 528              [Ca+2]
# 529  C(COCCOCCOCCOCCO)O
# 530  C(COCCOCCOCCOCCO)O
# 531  C(COCCOCCOCCOCCO)O
# 532  C(COCCOCCOCCOCCO)O
#
# [533 rows x 5 columns]

# %% [markdown]
# # **Task 2
# ** From the previusly made CSV retrieve the IC50/Kd values from ChemBL/BindingDB to determine if any of the co-crystallized ligands have tabulated IC50.**
#
# **Trying with either BindingDB or ChemBL**

# %%
# Try querying BindingDB
ligands = df2['LIGAND_NAME']
def get_bindingdb_data(compound_name, activity_type="IC50"):
  for ligand in ligands:

    url = f"https://bindingdb.org/bind/BindingDBrestful/getLigandsByIC50/{ligand}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.text
        if data:
            return pd.read_csv(pd.compat.StringIO(data))
        else:
            return None
    else:
        return None

# Apply the function to each row in the DataFrame
bindingdb_data = get_bindingdb_data(ligands)

# Display the data
if bindingdb_data is not None and not bindingdb_data.empty:
    print(bindingdb_data[['Ki (nM)', 'Kd (nM)', 'IC50 (nM)', 'PubChem CID']])
else:
    print("No data found.")
# Out:
# No data found.

# %% [markdown]
# **Using BindingDB shows that IC50/Kd values are not available** *No Data Found*
#
# Try ChemBL

# %%
# let's try  ChemBL, but we need to install the extra client for this
# !pip install chembl_webresource_client # install chembl web resource client to access the chembl ids of the ligands
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.1 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.7 MB/s eta 0:00:00
# Downloading cattrs-24.1.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.3 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.1 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %%
# now get the chemBL ids to query the chemBL API
from chembl_webresource_client.new_client import new_client
def get_chembl_id(ligands):
    url = f"https://www.ebi.ac.uk/chembl/api/data/molecule.json?pref_name={ligands}&limit=1"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['molecules']:
            return data['molecules'][0]['molecule_chembl_id']
    return None

ligands = df2['LIGAND_NAME']
#df = pd.DataFrame(ligands)

# Apply the function to each ligand name to get ChEMBL IDs
df2['ChEMBL_ID'] = ligands.apply(get_chembl_id)

# %%
df2 # some ligands have chembl id available while some returned none
# Out:
#     PDBID   CODE                                        LIGAND_NAME smiles  \
# 0    8xjj  A1LVJ  5-[4-[[(1~{R})-1-[3-[bis(fluoranyl)methyl]-2-f...
# 1    8xjj    EDO                                     1,2-ETHANEDIOL
# 2    8xjj    EDO                                     1,2-ETHANEDIOL
# 3    8xjj    EDO                                     1,2-ETHANEDIOL
# 4    8xjj    EDO                                     1,2-ETHANEDIOL
# ..    ...    ...                                                ...    ...
# 528  6y44     CA                                        CALCIUM ION
# 529  6f08    1PE                               PENTAETHYLENE GLYCOL
# 530  6f08    1PE                               PENTAETHYLENE GLYCOL
# 531  6f08    1PE                               PENTAETHYLENE GLYCOL
# 532  6f08    1PE                               PENTAETHYLENE GLYCOL
#
#                  SMILES      ChEMBL_ID
# 0                  None           None
# 1                C(CO)O           None
# 2                C(CO)O           None
# 3                C(CO)O           None
# 4                C(CO)O           None
# ..                  ...            ...
# 528              [Ca+2]           None
# 529  C(COCCOCCOCCOCCO)O  CHEMBL1229766
# 530  C(COCCOCCOCCOCCO)O  CHEMBL1229766
# 531  C(COCCOCCOCCOCCO)O  CHEMBL1229766
# 532  C(COCCOCCOCCOCCO)O  CHEMBL1229766
#
# [533 rows x 6 columns]

# %%
df2.isna().sum()
# Out:
# PDBID            0
# CODE             0
# LIGAND_NAME      0
# smiles           0
# SMILES          46
# ChEMBL_ID      322
# dtype: int64

# %% [markdown]
# **There are 322 ligands with unavailable ChemBL_IDs**
#
# But lets see the available ones

# %%
chembl_ids = df2.dropna(subset=['ChEMBL_ID'])
chembl_ids
# Out:
#     PDBID CODE           LIGAND_NAME smiles              SMILES      ChEMBL_ID
# 34   7avl  IMD             IMIDAZOLE                  C1=CN=CN1      CHEMBL540
# 35   7avl  IMD             IMIDAZOLE                  C1=CN=CN1      CHEMBL540
# 36   7avl  IMD             IMIDAZOLE                  C1=CN=CN1      CHEMBL540
# 37   7avl  IMD             IMIDAZOLE                  C1=CN=CN1      CHEMBL540
# 38   7avl  IMD             IMIDAZOLE                  C1=CN=CN1      CHEMBL540
# ..    ...  ...                   ...    ...                 ...            ...
# 456  6d5g  FMT           FORMIC ACID                     C(=O)O   CHEMBL116736
# 529  6f08  1PE  PENTAETHYLENE GLYCOL         C(COCCOCCOCCOCCO)O  CHEMBL1229766
# 530  6f08  1PE  PENTAETHYLENE GLYCOL         C(COCCOCCOCCOCCO)O  CHEMBL1229766
# 531  6f08  1PE  PENTAETHYLENE GLYCOL         C(COCCOCCOCCOCCO)O  CHEMBL1229766
# 532  6f08  1PE  PENTAETHYLENE GLYCOL         C(COCCOCCOCCOCCO)O  CHEMBL1229766
#
# [211 rows x 6 columns]

# %% [markdown]
# **There are 211 rows with chembl_ids, so we can do this by iterating through the list**

# %%
import requests
import pandas as pd

# Function to fetch bioactivity data for a ChEMBL ID from ChEMBL API
def get_bioactivity_data(chembl_ids):
    url = f"https://www.ebi.ac.uk/chembl/api/data/activity.json?molecule_chembl_id={chembl_ids}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        activities = data.get('activities', [])

        # Collect relevant data (IC50, Ki, Kd)
        bioactivity_data = []
        for activity in activities:
            activity_type = activity.get('standard_type')
            standard_value = activity.get('standard_value')
            standard_units = activity.get('standard_units')
            if activity_type in ['IC50', 'Ki', 'Kd']:
              for chembl_id in chembl_ids:
                bioactivity_data.append({
                    'chembl_id': chembl_id,
                    'activity_type': activity_type,
                    'value': standard_value,
                    'units': standard_units
                })
        return bioactivity_data
    else:
        print(f"Error fetching data for ChEMBL ID: {chembl_ids} - Status Code: {response.status_code}")
        return []


chembl_ids = chembl_ids.to_numpy()
chembl_ids = chembl_ids.flatten()
chembl_ids = chembl_ids.tolist()

# Initialize a list to collect all bioactivity data
all_bioactivity_data = []

# Loop through the ChEMBL IDs and collect bioactivity data
for chembl_id in chembl_ids:
    bioactivity_data = get_bioactivity_data(chembl_id)
    all_bioactivity_data.extend(bioactivity_data)

# Convert the list of bioactivity data to a DataFrame
bioactivity_df = pd.DataFrame(all_bioactivity_data)

# Display the resulting bioactivity DataFrame
if not bioactivity_df.empty:
    print(bioactivity_df)
else:
    print("No bioactivity data found for the given ChEMBL IDs.")
# Out:
# Error fetching data for ChEMBL ID: None - Status Code: 500
# Error fetching data for ChEMBL ID: None - Status Code: 500

# %% [markdown]
# **Wow!!!!, Finally, The query of chemBL API  with chembl_ids succesfully returned the data, for available activity/affinity types IC50/k/ki data hence next task!**
#
# *Lets visualize this in DataFrame*

# %%
# Convert the list of bioactivity data to a DataFrame
bioactivity_df = pd.DataFrame(all_bioactivity_data)
bioactivity_df

# %%
unique_activity_types = bioactivity_df['activity_type'].unique()
print(unique_activity_types)

# %% [markdown]
# **The unique function shows that only IC50 and ki are available**

# %% [markdown]
# # **Task 3
# **From ChemBL/BindingDB the activities of the ligands screened against the target.**

# %% [markdown]
# **To retrieve activities of ligands found in SOS1 from chemBL**
#
# **We need to get the target_chembl_id**
#
# **Let try this programmatically, else, we do manualy**

# %%
# To retrieve activities of ligands found in SOS1 from chemBL
# We need to get the target_chembl_id
#Let try this programmatically, else, we do manualy.

uniprot_id = 'Q07889'
def get_target_chembl_id(uniprot_id):
    url = f"https://www.ebi.ac.uk/chembl/api/data/target.json?target_components__accession={uniprot_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['targets']:
            return data['targets'][0]['target_chembl_id']
    return None


target_chembl_id = get_target_chembl_id(uniprot_id)

print(f"Target ChEMBL ID for SOS1 (Q07899): {target_chembl_id}")

# %% [markdown]
# **Beautiful, chembl_id fo SOS1 Q07889 is CHEMBL2079846**
#
# ***Retrieve Ligand Activities!!***

# %%
SOS1_ID = 'CHEMBL2079846'
def get_chembl_activities(SOS1_ID, activity_type="IC50"):
    url = f"https://www.ebi.ac.uk/chembl/api/data/activity.json?target_chembl_id={target_chembl_id}&activity_type={activity_type}&limit=1000"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data['activities']
    else:
        return None

# Apply the function to get activities
activity_types = ["IC50", "kd", "ki"]   # You can specify other types like "Kd", "Ki", etc.
for activity_type in activity_types:
  activities = get_chembl_activities(SOS1_ID, activity_type)

# Convert to a DataFrame for easier analysis
if activities:
    df_activity = pd.DataFrame(activities)
    print(df_activity[['molecule_chembl_id', 'value', 'units', 'assay_description']])
else:
    print("No activity data found.")

# %%
df_activity.head()

# %% [markdown]
# **This is the table of activities of the co-crystalized ligands associated with SOS1 with uniprot_id Q07899**

# %%
df_activity.info() #get full info

# %%
df_activity.describe()

# %% [markdown]
# **The activity types of the ligands available**

# %%
df_activity['type']

# %% [markdown]
# # **Build a QSAR model**
#
# QSAR = Quantitative Structure Activity Relationship.
#
# This model will estimate how the structures of the ligands will predict the activity/affinity of the respective ligands.
#
# These avtivities could be:
#
# IC50: Half maximal inhibitors concentration
#
# ki: Inhibition constant
#
# kd: dissociation constant
#
# **To do these,** we need to convert chemical structures to molecular descriptors.
#
# **the descriptors needed for this model are:
#
# **the molecular weight and Logp**
#
# **molecular weight can be gotten from their smiles programatically**
#
# **then LogP from the molecular weights**

# %%
# I want to use RandomForestRegressor estimator/model.
from rdkit import Chem
from rdkit.Chem import Descriptors # we need to convert chemical structures to molecular descriptors

# %%
# the descriptors needed for this model are the molecular weight and Logp
# molecular weight can be gotten from their smiles
# then LogP from the molecular weights

# read smiles from the DataFrame df2 with information about co-crystalized ligands
canonical_smiles = df2['SMILES']
molecules = df2['LIGAND_NAME']

# Calculate molecular descriptors, i.e molecular weight and LogP
def safe_mol_from_smiles(smiles):
    try:
        return Chem.MolFromSmiles(smiles)
    except:
        return None

df2['molecule'] = df2['SMILES'].apply(lambda x: safe_mol_from_smiles(x))
molecular_weight = []
LogP = []
for mol in df2['molecule']:
  if mol is not None:
    molecular_weight.append(Descriptors.MolWt(mol))
    LogP.append(Descriptors.MolLogP(mol))
    print(f"Molecular Weight: {molecular_weight}")
    print(f"LogP: {LogP}")
  else:
    molecular_weight.append(None)
    LogP.append(None)

# turn them to DataFrame to visualize better
df3 = pd.DataFrame(molecular_weight)
df4 = pd.DataFrame(LogP)

# %%
df3 # molecular weight

# %%
df4 #LogP

# %% [markdown]
# **Merge molecular weight and Logp to a single DataFrame**

# %%
# merge molecular weight and LogP in a DataFrame
merge = pd.concat([df3, df4], axis=1)

merge.columns = ['molecular_weight', 'LogP']
merge

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of molecular weights
plt.figure(figsize=(7, 5))
sns.histplot(merge['molecular_weight'], bins=30, kde=True)
plt.title('Distribution of Molecular Weights')
plt.xlabel('Molecular Weight')
plt.ylabel('Frequency')

# %% [markdown]
# **Show relationship/correlation type between molecular weight and Logp**

# %%
plt.plot(merge['molecular_weight'], merge['LogP'], 'D')
plt.xlabel('Molecular Weight')
plt.ylabel('LogP')
plt.title('Molecular Weight vs. LogP')
plt.show()

# %% [markdown]
# **It is rougly a positive correlation**
# **Logp increases with molecular weight**

# %% [markdown]
# **This portrays a positive correlation and a Linear Regression estimator can be used to model the system**

# %% [markdown]
# **Incorporate molecular weight and Logp into df2**

# %%
# add them to df2
df2['molecular_weight'] = df3
df2['LogP'] = df4
df2

# %%
unique_ligand = df2['LIGAND_NAME'].unique()
unique_ligand

# %%
len(unique_ligand), len(df2['LIGAND_NAME'])

# %%
df_activity['standard_value'] # standard vaule is an important activity feature of the ligands

# %%
df2.info()

# %%
df_activity.info()

# %% [markdown]
# **Check if the number of rows of the molecular weight/Logp are consistent**

# %%
X = df2[['molecular_weight', 'LogP']]
y = df_activity['standard_value']
print(len(X))
print(len(y))

# %% [markdown]
# **Building model on this X and y split will return error of inconsistence dimensions, hence needs to be trimmed to match as follows**

# %%
if len(X) > len(y):
    X_trimmed = X.iloc[:len(y)]
    y_trimmed = y
elif len(y) > len(X):
    y_trimmed = y.iloc[:len(X)]
    X_trimmed = X
else:
    X_trimmed = X
    y_trimmed = y

# %%
print(len(X_trimmed))
print(len(y_trimmed)) # Now the dimensions are equal and can be modeled with Regression model (RandonForestRegressor)

# %% [markdown]
# **The number of rows are equal from sampling**
# **can be modeled with Regression model (RandonForestRegressor)**

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import median_absolute_error

#  convert standard values to float data type and drop NAN rows
y = df_activity['standard_value'].astype(float).dropna()
X = df2[['molecular_weight', 'LogP']].dropna()  # Drop rows with missing descriptors

if len(X) > len(y):
    X_trimmed = X.iloc[:len(y)]
    y_trimmed = y
elif len(y) > len(X):
    y_trimmed = y.iloc[:len(X)]
    X_trimmed = X
else:
    X_trimmed = X
    y_trimmed = y

# Split the data into training and testing sets
X_trimmed_train, X_trimmed_test, y_trimmed_train, y_trimmed_test = train_test_split(X_trimmed, y_trimmed,
                                                    test_size=0.2,
                                                    random_state=42)
# random_state does the work of random seed to retrict to a set of the possible random combinations

# Create a Random Forest Regressor model
model = RandomForestRegressor() # instantiate the estimator

# Fit the model to the training data
model.fit(X_trimmed_train, y_trimmed_train)

# Make predictions on the test data
y_pred = model.predict(X_trimmed_test)

# Evaluate the model
mse = mean_squared_error(y_trimmed_test, y_pred)
r2 = r2_score(y_trimmed_test, y_pred)
mae = mean_absolute_error(y_trimmed_test, y_pred)
rmse = np.sqrt(mse)
evs = explained_variance_score(y_trimmed_test, y_pred)
median_ae = median_absolute_error(y_trimmed_test, y_pred)


print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
print(f"Explained Variance Score: {evs}")
print(f"Median Absolute Error: {median_ae}")

# %%
# !python -m pip install https://github.com/MolecularAI/QSARtuna/releases/download/3.1.1/qsartuna-3.1.1.tar.gz

# %% [markdown]
# **Try this modelling with QSARtuna**

# %%
# !python --version

# %% [markdown]
# **My python version mismatches the requirement for QSARtuna, hence not installed, So I stick to RandomForest Regressor model**

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %% [markdown]
# # **Task 3 Perform Molecular Matched Pair Analysis**
# **I am using rdkit**
#
# Molecular Matched Pair Analysis (MMPA) is a method used in medicinal chemistry and cheminformatics to analyze the impact of small structural changes (transformations) on the properties of chemical compounds. The goal is to understand how specific molecular modifications affect biological activity, physicochemical properties, or other relevant metrics, such as solubility, toxicity, or pharmacokinetics.

# %%
from rdkit import Chem # rDkit = Reaction Data kit
from rdkit.Chem import rdFMCS # rdFMCS = RDkit Find Maximum Common Substructure

# df2' contains my molecules/ligands with SMILES
smiles_list = df2['SMILES'].dropna().tolist()  # Read as list from DataFrame, removing missing SMILES

# Perform MMP analysis
pairs = []
for i in range(len(smiles_list)):
    for j in range(i + 1, len(smiles_list)):
        mol1 = Chem.MolFromSmiles(smiles_list[i])
        mol2 = Chem.MolFromSmiles(smiles_list[j])
        if mol1 and mol2:
            mcs = rdFMCS.FindMCS([mol1, mol2])
            if mcs.numAtoms > 0:  # Check if a common substructure was found
                pairs.append((smiles_list[i], smiles_list[j], mcs.smartsString))
# SMARTS = SMiles ARbitrary Target Specification (designed for querying and Identifying patterns or substructures within molecule)
# SMILES = Simplified Molecular Input Line Entry (Reperesents whole molecule)
# Result processing and Analysis
print("MMP Analysis Results:")
for smiles_a, smiles_b, mcs_smarts in pairs:
    print(f"Molecule 1: {smiles_a}")
    print(f"Molecule 2: {smiles_b}")
    print(f"MCS SMARTS: {mcs_smarts}")
    print("-" * 40)
# present this in dataframe for easy visualizzation
#df_match_pair

# %% [markdown]
# **DataFrame of matched pairs**

# %%
# present this in dataframe for easy visualizzation
df_match_pair = pd.DataFrame(pairs, columns=['Molecule 1', 'Molecule 2', 'MCS SMARTS'])
df_match_pair.head(10)

# %% [markdown]
# # **Perfom Free Wilson Analysis**
#
# Free-Wilson analysis is a method used in medicinal chemistry and quantitative structure-activity relationship (QSAR) studies to assess how different chemical substituents influence biological activity. It involves systematically modifying the substituents on a core molecule and determining how these modifications affect the activity of the compound.

# %%
# !pip install mordred
from mordred import Calculator, descriptors

# %%
# !pip install papyrus-python

# %% [markdown]
# **papyrus version not installing, Hence I am using the model method for Free-wilson analysis**
#
# Estimator = LinearRegressor form scikit learn linear model

# %%
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd

# standard_value from the activity data is set as target for our model.
y = df_activity['standard_value'].astype(float).dropna() # standard value reperesent the biological activity of the molecule
X = df2[['molecular_weight', 'LogP']].dropna()  # Drop rows with missing descriptors

# One-hot encode the presence/absence of each substructure (from MMP analysis)
substructures = list(set([mcs for _, _, mcs in pairs]))
substructure_presence = pd.DataFrame(index=df2.index, columns=substructures)
for i, row in df2.iterrows():
    for substructure in substructures:
        substructure_presence.loc[i, substructure] = int(substructure in row[['SMILES']]) # gets the presence of the substructure as true or false 'boolean' and returned it as int

# Combine descriptors and substructure presence
X = pd.concat([X, substructure_presence], axis=1).dropna()

# Align dataframes to have the same indices
common_index = X.index.intersection(y.index)
X = X.loc[common_index]
y = y.loc[common_index]

# Perform linear regression (Free-Wilson analysis)
model = LinearRegression()
model.fit(X, y)

# Analyze coefficients
coefficients = pd.DataFrame({'Feature': X.columns, 'Coefficient': model.coef_})
print(coefficients.sort_values('Coefficient', key=abs, ascending=False))

# %%
# present this in dataframe for easy visualization
coefficients.sort_values('Coefficient', key=abs, ascending=False)

# %% [markdown]
# Analysis of the Coefficients:
# LogP (-581.896214):
#
# **Interpretation:** LogP has a strong negative coefficient, indicating that as LogP increases (molecules become more hydrophobic), the biological activity decreases significantly.
# Possible Reason: A high LogP suggests that a molecule is more hydrophobic, which might reduce its solubility or increase its likelihood of being trapped in cell membranes, thus negatively impacting its biological activity in certain assays.
#
# **Molecular Weight (7.460326):**
#
# **Interpretation:** Molecular weight has a positive coefficient, suggesting that as the molecular weight increases, biological activity increases (though the effect is much smaller than LogP's impact).
# Possible Reason: Heavier molecules might interact more strongly with their targets or possess more functional groups, enhancing biological activity. However, this positive effect is relatively minor.
#
# **Substructures with Zero Coefficients (0.000000):**
#
# [#6]-,:#6-,:[...] (Feature 457)
#
# [#6]-,:[#6](:[#6]:#6-[#6]-[#7]:,-[#6]... (Feature 458)
#
# **Interpretation:** These substructures have zero coefficients, indicating that the presence or absence of these specific substructures does not contribute to biological activity in this dataset.
#
# Possible Reason: The substructures might not be relevant to the activity being studied or may not vary significantly among the molecules, thus having no discernible impact on the outcome.

# %% [markdown]
# # **Docking**

# %% [markdown]
# **Needed tools:
#
# Gnina,
#
# Smina,
#
# rdkit,
#
# pandas,
#
# maptplotlib
#
# **
#
# **From documentation, Gnina is not a python package, but can be run on python script with subprocees**

# %%
import requests
import os

# Define the PDB ID and output file path
pdb_id = "5OVF"
output_file = "5OVF.pdb"

# Construct the URL to download the PDB file from rcsb pdb site
url = f"https://files.rcsb.org/download/{pdb_id}.pdb"

# Download the PDB file
response = requests.get(url)

# Save the PDB file
with open(output_file, "wb") as f:
    f.write(response.content)

print(f"PDB file {pdb_id}.pdb downloaded successfully.")

# %% [markdown]
# **lets view the structure**

# %%
# !pip install pymol-open-source

# %% [markdown]
# **pymol not installing**
#
# **Lets try nglview**

# %%
#lets try nglview
# !pip install nglview

# %%
import nglview as nv

# Load the PDB file
view = nv.show_file("5OVF.pdb")

# Display the structure
view

# %%
view.render_image()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %% [markdown]
# **Not showing properly with NGL vieing lets try py3dmol**

# %%
# !pip install py3Dmol # install Py3Dmol

# %%
import py3Dmol

# Create a viewer
view = py3Dmol.view(width=400, height=300)

# Load the PDB file content
with open('5OVF.pdb', 'r') as file:
    pdb_data = file.read()

# Add the structure to the viewer
view.addModel(pdb_data, 'pdb')

# Set the visualization style (e.g., cartoon, sticks)
view.setStyle({'cartoon': {'color': 'spectrum'}})

# Center and zoom
view.zoomTo()

# Show the structure

view.show()

# %% [markdown]
# **Beautiful, structure is visualized on Py3Dmol**

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# **The pdb file format is not compactible for docking on docking tools, we need to convert to pdbqt**
#
# **Install openbabel, to convert pdb to pdbqt**

# %%
# install openbabel to help convert the pdb file for the docking executable pdbqt format
# !apt-get update
# !apt-get install -y openbabel

# %% [markdown]
# # Docking Task 1
# **write an automated pipeline using Smina to perform a virtual screening experiment on SOS1 (PDB ID: 5OVF) with at least 10 small molecules that are both biologically relevant and synthetically accessible.**

# %%
# Install dependencies
# !apt-get install -y cmake libboost-all-dev

# Clone the Gnina repository
# !git clone https://github.com/gnina/gnina.git

# Navigate to the gnina directory
# %cd gnina

# Build Gnina
# !mkdir build
# %cd build
# !cmake ..
# !make

# Install Gnina
# !make install

# %% [markdown]
# # Installing Gnina gave a lot of problem, I want to try Smnia

# %%
# !apt-get update
# !apt-get install -y build-essential cmake wget openbabel

# %%
# Build smina from source
# !apt-get update
# !apt-get install -y wget

# %%
# clone smina
# !git clone https://github.com/mwojcikowski/smina.git

# %% [markdown]
# **Docking with Smina**

# %%
# Prepare protein
# !obabel 5OVF.pdb -O protein.pdbqt -xr -p 7.4

# Download sample biologically relevant and synthetically accessible molecules
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/ace.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/benzene.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/ind.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/pyridine.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/toluene.sdf
# Add more molecules here (at least 10) ...

# Convert ligands to pdbqt
# !obabel *.sdf -O ligands.pdbqt -m

# Define docking parameters
receptor = "protein.pdbqt"
ligands = "ligands.pdbqt"
out = "docking_results.sdf"
center_x = -7.5
center_y = 23.5
center_z = 21.0
size_x = 20
size_y = 20
size_z = 20

# Run Smina
# !smina --receptor $receptor --ligand $ligands --center_x $center_x --center_y $center_y --center_z $center_z --size_x $size_x --size_y $size_y --size_z $size_z --out $out

# %%
# !ls -l smina

# %%
# !apt-get install -y openbabel

# %%
# !pip install openbabel-wheel

# %%
# !apt-get update
# !apt-get install -y build-essential cmake

# %%
# Install dependencies
# !apt-get install -y build-essential cmake wget openbabel

# Clone the Smina repository (if not already cloned)
# !git clone https://github.com/mwojcikowski/smina.git

# Navigate to the smina directory
# %cd smina

# Build Smina (if not already built)
# !mkdir build
# %cd build
# !cmake .. # CMake is a build system generator that automates the process of configuring and generating build files for software projects across different platforms.
# !make

# Install Smina
# !make install
# !make

# Go back to the main directory
# %cd ../..

# Prepare protein
# !obabel 5OVF.pdb -O protein.pdbqt -xr -p 7.4

# Download sample biologically relevant and synthetically accessible molecules  5ovf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/ace.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/benzene.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/ind.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/pyridine.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/toluene.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/adamantane.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/benzocaine.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/butane.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/caffeine.sdf
# !wget -q https://raw.githubusercontent.com/mwojcikowski/smina/master/test/ethanol.sdf

# Convert ligands to pdbqt
# !obabel *.sdf -O ligands.pdbqt -m

# Define docking parameters
receptor = "protein.pdbqt"
ligands = "ligands.pdbqt"
out = "docking_results.sdf"
center_x = -7.5
center_y = 23.5
center_z = 21.0
size_x = 20
size_y = 20
size_z = 20

# Run Smina
# !smina --receptor $receptor --ligand $ligands --center_x $center_x --center_y $center_y --center_z $center_z --size_x $size_x --size_y $size_y --size_z $size_z --out $out

# %% [markdown]
# **Smina giving issues, even after succefully installed and cloned, I want to try plants**

# %%
# confirming if openbabel is successfully installed
import openbabel
from openbabel import pybel

print("OpenBabel and Pybel are successfully installed!")

# %% [markdown]
# **I cant get through with Gnina, Smina and Plants, I need further education, But i can make do with autodock vina**

# %% [markdown]
# **Trying with autodock vina**

# %%
# Install required packages
# !apt-get update
# !apt-get install -y python3-pip
# !pip install biopython

# Install AutoDock Vina
# !wget https://github.com/ccsb-scripps/AutoDock-Vina/releases/download/v1.2.3/vina_1.2.3_linux_x86_64.tar.gz
# !tar -xzf vina_1.2.3_linux_x86_64.tar.gz
# !chmod +x vina

# %%
from openbabel import pybel
import subprocess

ligands_sdf = '/content/drive/MyDrive/Colab Notebooks/ligands.sdf'
receptor_pdb = '/content/drive/MyDrive/Colab Notebooks/5OVF.pdb'

# Define paths
receptor_pdb = '5OVF.pdb'
ligands_sdf = 'ligands.sdf'
receptor_pdbqt = 'receptor.pdbqt'
ligands_pdbqt = 'ligands.pdbqt'

# Convert receptor PDB to PDBQT format
receptor = pybel.readfile('pdb', receptor_pdb).__next__() # Since pybel.readfile() returns an iterator, this command gets the first (and only) receptor molecule in the file.
receptor.removeh()  # Remove hydrogens
receptor.addh()     # Add hydrogens
receptor.write('pdbqt', receptor_pdbqt, overwrite=True)

# Convert ligands SDF to PDBQT format
ligands = pybel.readfile('sdf', ligands_sdf)
for ligand in ligands:
    ligand.addh()  # Add hydrogens
    ligand.write('pdbqt', ligands_pdbqt, overwrite=True)

print(f"Converted receptor to {receptor_pdbqt} and ligands to {ligands_pdbqt}.")

# %%
# Create AutoDock Vina configuration file
config_file = 'config.txt'
with open(config_file, 'w') as f:
    f.write(f"""# AutoDock Vina configuration file
    receptor = {receptor_pdbqt}
    ligand = {ligands_pdbqt}
    center_x = 0
    center_y = 0
    center_z = 0
    size_x = 20
    size_y = 20
    size_z = 20
    num_modes = 9
    exhaustiveness = 8
    """)
import subprocess

# Define the output file path
output_file = 'docking_output.pdbqt'
log_file = 'docking_log.txt'

# Run AutoDock Vina
result = subprocess.run(['./vina', '--config', config_file, '--out', output_file, '--log', log_file], capture_output=True, text=True)

# Print results
print('Vina Output:')
print(result.stdout)
print('Vina Errors:')
print(result.stderr)

# %%
# Print docking log
with open(log_file, 'r') as f:
    log_contents = f.read()
print('Docking Log:')
print(log_contents)

# %% [markdown]
# # Docking Task 2
# **Write an automated pipeline using Gnina (or alternative tools) to perform covalent docking on G12C. Utilize CovPDB to identify the appropriate warhead for covalent docking. Refer to the ChemBL/BindingDB ligands for inspiration.**

# %%
# !pip install covpdb
import covpdb
protein_id = '6OIM'
warheads = covpdb.get_warheads(protein_id)
print(warheads)

# %%
# Use cvpdb to identify warhead
# !pip install covpdb
import covpdb
import requests
protein_id = '6OIM'


def fetch_covpdb_ligands(protein_id):
    url = f'https://covpdb.cc/ligands/{protein_id}'  # Assuming CovPDB API or web interface
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()  # if it returns ajson data
    else:
        print(f"Error fetching data from CovPDB: {response.status_code}")
        return None

def identify_warhead(ligands):
    for ligand in ligands:
        if ligand['type'] == 'warhead':  # Assuming the data categorizes the ligands
            return ligand['smiles']  # Return the SMILES of the warhead
    return None

# Step to execute for 6OIM
protein_id = '6OIM'  # PDB ID for the target protein
ligands = fetch_covpdb_ligands(protein_id)

if ligands:
    warhead_smiles = identify_warhead(ligands)
    if warhead_smiles:
        print(f"Identified warhead for covalent docking in 6OIM: {warhead_smiles}")
    else:
        print("No warhead identified in CovPDB data for 6OIM.")
else:
    print("No ligand data retrieved from CovPDB.")

# %% [markdown]
# # Docking Task 2
#
# **write a complete pipeline that:**
#
# **Enumeratesthe GBB Reaction using suitably selected building blocks (from Reaxys or Enamine) obtained via SMARTS strings**

# %%
# Hint:
# smarts_string = "[#7:3]~[#6:1]-[#7:2].[C-:4]#[N+:5].[#6:7]=O>>[#7:5]-[#6:4]-1=[#6:7]-[#7:2]=[#6:1]-[#7:3]-1"

# !pip install rdkit-pypi
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

# Define the GBB reaction SMARTS string
smarts_string = "[#7:3]~[#6:1]-[#7:2].[C-:4]#[N+:5].[#6:7]=O>>[#7:5]-[#6:4]-1=[#6:7]-[#7:2]=[#6:1]-[#7:3]-1"

# Create a reaction from the SMARTS string
rxn = AllChem.ReactionFromSmarts(smarts_string)


# Building blocks
building_blocks = [
    ("[#7H]~C-N", "amine"),  # Primary amine
    ("C#N", "isonitrile"),  # Isonitrile
    ("C=O", "aldehyde"),  # Aldehyde
]

# Generate possible products
products = []
for amine_smarts, amine_name in building_blocks:
  for isonitrile_smarts, isonitrile_name in building_blocks:
    for aldehyde_smarts, aldehyde_name in building_blocks:
      amine = Chem.MolFromSmarts(amine_smarts)
      isonitrile = Chem.MolFromSmarts(isonitrile_smarts)
      aldehyde = Chem.MolFromSmarts(aldehyde_smarts)
      if amine and isonitrile and aldehyde:
        try:
          ps = rxn.RunReactants((amine, isonitrile, aldehyde))
          for p in ps:
            products.append((p[0], f"{amine_name}-{isonitrile_name}-{aldehyde_name}"))
        except:
          pass

# Draw the products
if products:
  for product, name in products:
    print(name)
    Draw.MolToImage(product)
else:
  print("No products found.")

# %% [markdown]
# # **Molecular Dynamics Simulations of 5OVF Protein with GROMACS**
# ** Task 1**
# **GROMACS: GROningen MAchine for Chemical Simulations**

# %%
# call the parameter files from drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# confirm availability of my parameter files on drive
files = os.listdir('/content/drive/MyDrive/Colab Notebooks')
print(files)
import pandas as pd
fl =pd.DataFrame(files)
fl.to_csv('files.csv' , index=False)
fl

# %%
# call the parameter files from drive
ions = '/content/drive/MyDrive/Colab Notebooks/ions.mdp'
minim = '/content/drive/MyDrive/Colab Notebooks/minim.mdp'
nvt = '/content/drive/MyDrive/Colab Notebooks/nvt.mdp'
npt = '/content/drive/MyDrive/Colab Notebooks/npt.mdp'
md = '/content/drive/MyDrive/Colab Notebooks/md.mdp'

with open(ions, 'r') as file:
    content_ions = file.read()
with open(minim, 'r') as file:
    content_minim = file.read()
with open(nvt, 'r') as file:
  content_nvt = file.read()
with open(npt, 'r') as file:
  content_npt = file.read()
with open(md, 'r') as file:
  content_md = file.read
content_ions
content_minim
content_nvt
content_npt
content_md

# %% [markdown]
# # Simple Molecular Dynamics Simulation of 5OVF with Gromacs
# **GROMACS:**
# Gronigen Machine for Molecular Simulation

# %%
# Create a directory for the simulation
# !mkdir simulation

# Copy the protein file to the simulation directory
# !cp 5OVF.pdb simulation/

# Go to the simulation directory
# %cd simulation

# Generate topology
# !gmx pdb2gmx -f 5OVF.pdb -o 5OVF_processed.gro -ff amber99sb -water tip3p

# Define box
# !gmx editconf -f 5OVF_processed.gro -o 5OVF_boxed.gro -c -d 1.0 -bt cubic

# Solvate the system
# !gmx solvate -cp 5OVF_boxed.gro -cs spc216.gro -o 5OVF_solvated.gro -p topol.top

# Add ions
# !gmx grompp -f /content/drive/MyDrive/Colab\ Notebooks/ions.mdp -c 5OVF_solvated.gro -p topol.top -o ions.tpr
# !gmx genion -s ions.tpr -o 5OVF_ionized.gro -p topol.top -pname NA -nname CL -neutral

# Energy minimization
# !gmx grompp -f /content/drive/MyDrive/Colab\ Notebooks/minim.mdp -c 5OVF_ionized.gro -p topol.top -o em.tpr
# !gmx mdrun -v -deffnm em -cpi

# NVT equilibration
# !gmx grompp -f /content/drive/MyDrive/Colab\ Notebooks/nvt.mdp -c em.gro -p topol.top -o nvt.tpr
# !gmx mdrun -v -deffnm nvt -cpi

# NPT equilibration
# !gmx grompp -f /content/drive/MyDrive/Colab\ Notebooks/npt.mdp -c nvt.gro -p topol.top -o npt.tpr
# !gmx mdrun -v -deffnm npt -cpi

# Production MD run
# !gmx grompp -f /content/drive/MyDrive/Colab\ Notebooks/md.mdp -c npt.gro -p topol.top -o md.tpr
# !gmx mdrun -v -deffnm md -cpi

# Analyze the trajectory (example: RMSD)
# !gmx rms -s md.tpr -f md.xtc -o rmsd.xvg -tu ns

# Go back to the main directory
# %cd ..

# %%
# Convert the PDB file to Gromacs format
# !obabel 5OVF.pdb -O 5OVF.gro

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %% [markdown]
# # **Exploration**
# **Reinvent4**
# Generation and optimization of novel chemical structures that could potentially be developed into drugs.

# %%
# Assume we have a dataset of known SOS1 inhibitors in SMILES format
sos1_inhibitors = [
    "CC(C)Nc1ncnc2c1ncn2C1CCOC1",
    "CC(C)c1ccc(NC(=O)C2=Nc3ccc(N)c(Oc4ccc(Cl)cc4)c3N=C2)cc1",
    "O=C(Nc1ccc2c(c1)cc(n2)NC(=O)CCl)Nc1ccc2c(c1)cc(n2)NC(=O)CCl",
    "CC(C)C1=NC2=C(N1)N=C(NC2=O)C1CCCCC1",
    "CC1=C2N=C(NC3=C(N=CN3C)C2=NC=N1)C1CCCCC1"
]

# I am using just a simple representation instaed of the APIs and other tools
from rdkit import Chem
from rdkit.Chem import Draw

# Convert SMILES to RDKit molecules
rdkit_structures = [Chem.MolFromSmiles(smiles) for smiles in sos1_inhibitors]

# Visualization
structure_image = Draw.MolsToGridImage(molecules, molsPerRow=3)
structure_image

# Initialize REINVENT or a similar model and fine-tune on the SOS1 inhibitors dataset
# This step involves setting up the model, loading the dataset, and defining the reward function

# %%
# Generate new molecules
# This would typically involve running the model in inference mode and generating SMILES strings.
generated_smiles = [
    "CC(C)Nc1ccc(C2=NN=C(S2)N(C)C)cc1",  # smile 1
    "CC(C)C1=NN=C(N1)C1=NC=CC=N1C",       # smile 2
    "O=C(NC1=CC=CC=C1)N1CCCCN1C(=O)C",    # smile 3
    "CC1=NC(C)=C(C=C1)C1=CC=CN=C1",       # smile 4
    "C1CCN(CC1)C1=CC=CC=C1"               # smile 5
]

# Convert generated SMILES to RDKit molecules for visualization
generated_molecules = [Chem.MolFromSmiles(smiles) for smiles in generated_smiles]

# Visualize the generated molecules
img_generated = Draw.MolsToGridImage(generated_molecules, molsPerRow=3)
img_generated
